# %%
def moveZero(nums):
  n= len(nums)
  for idx,num in enumerate(nums):
    if num ==0:
      for idx2 in range(idx+1,n):
        print(idx2)
        num2=nums[idx2]
        if num2 !=0:
          nums[idx2] = num
          nums[idx] = num2
          break
  return nums
z = moveZero([0,1,1,2,0])
print(z)
# Out:
# 1
# 2
# 3
# 4
# [1, 1, 2, 0, 0]
